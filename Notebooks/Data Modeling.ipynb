# %% [markdown]
# # Machine Learning Modelling

# %% [markdown]
# **Data Preperation**

# %% [markdown]
# Before building models, the dataset is prepared by encoding categorical variables and selecting relevant features. The target variable for this analysis is customer churn.

# %%
import pandas as pd

df = pd.read_csv("data/Telco_customer_churn.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("data/Telco_customer_churn.csv")
#       4 df.head()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = df.drop(["CustomerID", "Churn Reason"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = df.drop(["CustomerID", "Churn Reason"], axis=1)
#
# NameError: name 'df' is not defined
